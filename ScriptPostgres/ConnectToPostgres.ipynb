# %%
import pandas
import psycopg2

try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "postgres",
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "postgres")

    cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("You are connected to - ", record,"\n")
    
    cursor = connection.cursor()
    
    create_table_query = '''CREATE TABLE if not exists dpc_covid19_ita_andamento_nazionale
          (data date,
          ricoverati_con_sintomi int,
          terapia_intensiva int,
          totale_ospedalizzati int,
          isolamento_domiciliare int,
          totale_attualmente_positivi int,
          nuovi_attualmente_positivi int,
          dimessi_guariti int,
          deceduti int,
          totale_casi int,
          tamponi int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from dpc_covid19_ita_andamento_nazionale")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/ProtezioneCivile/dpc-covid19-ita-andamento-nazionale_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO dpc_covid19_ita_andamento_nazionale VALUES ('"+str(list[0])+"', "+str(list[1])+", "+str(list[2])+", "+str(list[3])+", "+str(list[4])+", "+str(list[5])+", "+str(list[6])+", "+str(list[7])+", "+str(list[8])+", "+str(list[9])+", "+str(list[10])+")")
    

    
    create_table_query = '''CREATE TABLE if not exists dpc_covid19_ita_province
          (data date,
          denominazione_regione text,
          denominazione_provincia text,
          totale_casi int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from dpc_covid19_ita_province")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/ProtezioneCivile/dpc-covid19-ita-province_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO dpc_covid19_ita_province VALUES ('"+str(list[0])+"', '"+list[1].replace("'", " ")+"', '"+list[2].replace("'", " ")+"', "+str(list[3])+")")
    
    
    create_table_query = '''CREATE TABLE if not exists dpc_covid19_ita_regioni
          (data date,
          denominazione_regione text,
          ricoverati_con_sintomi int,
          terapia_intensiva int,
          totale_ospedalizzati int,
          isolamento_domiciliare int,
          totale_attualmente_positivi int,
          nuovi_attualmente_positivi int,
          dimessi_guariti int,
          deceduti int,
          totale_casi int,
          tamponi int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from dpc_covid19_ita_regioni")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/ProtezioneCivile/dpc-covid19-ita-regioni_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO dpc_covid19_ita_regioni VALUES ('"+str(list[0])+"', '"+list[1].replace("'", " ")+"', "+str(list[2])+", "+str(list[3])+", "+str(list[4])+", "+str(list[5])+", "+str(list[6])+", "+str(list[7])+", "+str(list[8])+", "+str(list[9])+", "+str(list[10])+", "+str(list[11])+")")
    
    
    create_table_query = '''CREATE TABLE if not exists COVID19_open_line_list
          (age int,
          sex text,
          city text,
          province text,
          country text,
          inWuhan int,
          date_confirmation date,
          symptoms text,
          chronic_disease_binary int,
          travel_in_Wuhan boolean,
          lives_in_Wuhan_binary boolean); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from COVID19_open_line_list")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/Kaggle/COVID19_open_line_list_clean.csv")
        dataset['age'] = dataset['age'].fillna('null')
        dataset['date_confirmation'] = dataset['date_confirmation'].fillna('null')
        for index, row in dataset.iterrows():
            row.replace
            list = row.tolist()
            if str(list[6])!='null':
                list[6] = "'"+str(list[6])+"'"
            cursor.execute("INSERT INTO COVID19_open_line_list VALUES ("+str(list[0])+", '"+str(list[1]).replace("'", " ")+"', '"+str(list[2]).replace("'", " ")+"', '"+str(list[3]).replace("'", " ")+"', '"+str(list[4]).replace("'", " ")+"', "+str(list[5])+", "+str(list[6])+", '"+str(list[7]).replace("'", " ")+"', "+str(list[8])+", "+str(list[9])+", "+str(list[10])+")")
    
    
    create_table_query = '''CREATE TABLE if not exists covid_19_clean_complete
          (ProvinceState text,
          CountryRegion text,
          Date date,
          Confirmed int,
          Deaths int,
          Recovered int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from covid_19_clean_complete")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/Kaggle/covid_19_clean_complete_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO covid_19_clean_complete VALUES ('"+str(list[0]).replace("'", " ")+"', '"+str(list[1]).replace("'", " ")+"', '"+str(list[2])+"', "+str(list[3])+", "+str(list[4])+", "+str(list[5])+")")
    
    
    create_table_query = '''CREATE TABLE if not exists istat_residenti
          (ITTER107 text,
          Territorio text,
          SEXISTAT1 int,
          Sesso text,
          ETA1 text,
          Età text,
          STATCIV2 int,
          Statocivile text,
          Value int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from istat_residenti")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/Istat/istat_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO istat_residenti VALUES ('"+list[0].replace("'", " ")+"', '"+list[1].replace("'", " ")+"', "+str(list[2])+", '"+list[3].replace("'", " ")+"', '"+list[4].replace("'", " ")+"', '"+list[5].replace("'", " ")+"', "+str(list[6])+", '"+list[7].replace("'", " ")+"', "+str(list[8])+" )")
    
    
    create_table_query = '''CREATE TABLE if not exists GDP_HEALTH_Per_Country
          (CountryCode text,
          CountryName text,
          GDP2016 decimal,
          HEALTHPerc2016 decimal,
          HEALTH2016 decimal); '''
    
    cursor.execute(create_table_query)
        
    cursor.execute("select count(*) from GDP_HEALTH_Per_Country")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/GDP/GDP_HEALTH_per_country_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO GDP_HEALTH_Per_Country VALUES ('"+list[0]+"', '"+list[1].replace("'", " ")+"', "+str(list[2])+", "+str(list[3])+", "+str(list[4])+")")
    
    
    create_table_query = '''CREATE TABLE if not exists france
          (date date,
          granularite text,
          maille_nom text,
          cas_confirmes int,
          deces int,
          reanimation int,
          hospitalises int,
          gueris int,
          depistes int); '''
    
    cursor.execute(create_table_query)
    
    cursor.execute("select count(*) from france")
    row = cursor.fetchone()
    if int(row[0])==0:
        dataset = pandas.read_csv("../../Datasets/Francia/france_clean.csv")
        for index, row in dataset.iterrows():
            list = row.tolist()
            cursor.execute("INSERT INTO france VALUES ('"+list[0]+"', '"+list[1].replace("'", " ")+"', '"+list[2].replace("'", " ")+"', "+str(list[3])+", "+str(list[4])+", "+str(list[5])+", "+str(list[6])+", "+str(list[7])+", "+str(list[8])+")")
    
    
    connection.commit()
    print("Table created successfully in PostgreSQL ")

#except (Exception, psycopg2.DatabaseError) as error :
#    print ("Error while creating PostgreSQL table", error)
#except (Exception, psycopg2.Error) as error :
#    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# {'user': 'postgres', 'dbname': 'postgres', 'host': '127.0.0.1', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 12.2, compiled by Visual C++ build 1914, 64-bit',)
#
# Table created successfully in PostgreSQL
# PostgreSQL connection is closed
