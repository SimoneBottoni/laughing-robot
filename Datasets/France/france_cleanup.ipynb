# %%
import pandas
#Load csv
franciaDataset = pandas.read_csv("francia.csv")
franciaDataset.head()
# Out:
#          date  granularite maille_code         maille_nom  cas_confirmes  \
# 0  2020-01-24  departement      DEP-16           Charente            0.0
# 1  2020-01-24  departement      DEP-17  Charente-Maritime            0.0
# 2  2020-01-24  departement      DEP-19            Corrèze            0.0
# 3  2020-01-24  departement      DEP-23             Creuse            0.0
# 4  2020-01-24  departement      DEP-24           Dordogne            0.0
#
#    deces  reanimation  hospitalises  gueris  depistes              source_nom  \
# 0    NaN          NaN           NaN     NaN       NaN  ARS Nouvelle-Aquitaine
# 1    NaN          NaN           NaN     NaN       NaN  ARS Nouvelle-Aquitaine
# 2    NaN          NaN           NaN     NaN       NaN  ARS Nouvelle-Aquitaine
# 3    NaN          NaN           NaN     NaN       NaN  ARS Nouvelle-Aquitaine
# 4    NaN          NaN           NaN     NaN       NaN  ARS Nouvelle-Aquitaine
#
#                                           source_url               source_type
# 0  https://www.nouvelle-aquitaine.ars.sante.fr/co...  agences-regionales-sante
# 1  https://www.nouvelle-aquitaine.ars.sante.fr/co...  agences-regionales-sante
# 2  https://www.nouvelle-aquitaine.ars.sante.fr/co...  agences-regionales-sante
# 3  https://www.nouvelle-aquitaine.ars.sante.fr/co...  agences-regionales-sante
# 4  https://www.nouvelle-aquitaine.ars.sante.fr/co...  agences-regionales-sante

# %%
#drop columns
franciaDataset.drop(columns=['maille_code','source_nom','source_url','source_type'],inplace=True)
franciaDataset.head()
# Out:
#          date  granularite         maille_nom  cas_confirmes  deces  \
# 0  2020-01-24  departement           Charente            0.0    NaN
# 1  2020-01-24  departement  Charente-Maritime            0.0    NaN
# 2  2020-01-24  departement            Corrèze            0.0    NaN
# 3  2020-01-24  departement             Creuse            0.0    NaN
# 4  2020-01-24  departement           Dordogne            0.0    NaN
#
#    reanimation  hospitalises  gueris  depistes
# 0          NaN           NaN     NaN       NaN
# 1          NaN           NaN     NaN       NaN
# 2          NaN           NaN     NaN       NaN
# 3          NaN           NaN     NaN       NaN
# 4          NaN           NaN     NaN       NaN

# %%
#group by date-granularite-maille_nom
grouped = franciaDataset.groupby(['date','granularite','maille_nom'])[['cas_confirmes','deces','reanimation','hospitalises','gueris','depistes']].max()
grouped.head(3000)
grouped = grouped.fillna(0)
grouped.head(3000)
# Out:
#                                                    cas_confirmes  deces  \
# date       granularite maille_nom
# 2020-01-24 departement Charente                              0.0    0.0
#                        Charente-Maritime                     0.0    0.0
#                        Corrèze                               0.0    0.0
#                        Creuse                                0.0    0.0
#                        Deux-Sèvres                           0.0    0.0
# ...                                                          ...    ...
# 2020-03-24 region      Nouvelle-Aquitaine                  789.0   14.0
#                        Occitanie                           900.0    0.0
#                        Pays de la Loire                    343.0   14.0
#                        Provence-Alpes-Côte d'Azur         1595.0   26.0
#                        Île-de-France                      6798.0    0.0
#
#                                                    reanimation  hospitalises  \
# date       granularite maille_nom
# 2020-01-24 departement Charente                            0.0           0.0
#                        Charente-Maritime                   0.0           0.0
#                        Corrèze                             0.0           0.0
#                        Creuse                              0.0           0.0
#                        Deux-Sèvres                         0.0           0.0
# ...                                                        ...           ...
# 2020-03-24 region      Nouvelle-Aquitaine                 66.0           0.0
#                        Occitanie                           0.0           0.0
#                        Pays de la Loire                   58.0           0.0
#                        Provence-Alpes-Côte d'Azur        133.0           0.0
#                        Île-de-France                       0.0           0.0
#
#                                                    gueris  depistes
# date       granularite maille_nom
# 2020-01-24 departement Charente                       0.0       0.0
#                        Charente-Maritime              0.0       0.0
#                        Corrèze                        0.0       0.0
#                        Creuse                         0.0       0.0
#                        Deux-Sèvres                    0.0       0.0
# ...                                                   ...       ...
# 2020-03-24 region      Nouvelle-Aquitaine            63.0       0.0
#                        Occitanie                      0.0       0.0
#                        Pays de la Loire              95.0       0.0
#                        Provence-Alpes-Côte d'Azur     0.0       0.0
#                        Île-de-France                  0.0       0.0
#
# [2454 rows x 6 columns]

# %%
#save to csv
grouped.to_csv('france_clean.csv', index=True)
