# %%
import pandas

lineListDataset = pandas.read_csv("COVID19_line_list_data.csv")
lineListDataset = lineListDataset.drop(["Unnamed: 3", "Unnamed: 21", "Unnamed: 22", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "summary", "If_onset_approximated", "symptom_onset", "link", "source", "symptom", "hosp_visit_date", "exposure_start", "exposure_end"],axis = 1)
lineListDataset["case_in_country"] = lineListDataset["case_in_country"].fillna(0)
lineListDataset["from Wuhan"] = lineListDataset["from Wuhan"].fillna(0)
lineListDataset["visiting Wuhan"] = lineListDataset["visiting Wuhan"].fillna(0)

# %%
lineListDataset
# Out:
#         id  case_in_country reporting date             location      country  \
# 0        1              0.0      1/20/2020  Shenzhen, Guangdong        China
# 1        2              0.0      1/20/2020             Shanghai        China
# 2        3              0.0      1/21/2020             Zhejiang        China
# 3        4              0.0      1/21/2020              Tianjin        China
# 4        5              0.0      1/21/2020              Tianjin        China
# ...    ...              ...            ...                  ...          ...
# 1080  1081              2.0      2/25/2020            Innsbruck      Austria
# 1081  1082              1.0      2/24/2020          Afghanistan  Afghanistan
# 1082  1083              1.0      2/26/2020              Algeria      Algeria
# 1083  1084              1.0      2/25/2020              Croatia      Croatia
# 1084  1085              1.0      2/25/2020                 Bern  Switzerland
#
# ...

# %%
from datetime import datetime as dt

var = 0
for tup in lineListDataset["recovered"]:
    if tup is not '0' and tup is not '1':
        print(pandas.to_datetime(tup))
        var += 1

print(var)
# Out:
# 2020-02-12 00:00:00
# 2020-02-12 00:00:00
# 2020-01-15 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 1899-12-30 00:00:00
# 2020-02-08 00:00:00
# 2020-02-14 00:00:00
# 2020-02-14 00:00:00
# 2020-02-14 00:00:00
# 2020-02-04 00:00:00
# 2020-02-14 00:00:00
# 2020-02-18 00:00:00
# 2020-02-05 00:00:00
# 2020-02-17 00:00:00
# 2020-02-09 00:00:00
# 2020-02-18 00:00:00
# 2020-02-18 00:00:00
# 2020-02-15 00:00:00
# 2020-02-27 00:00:00
# 2020-02-19 00:00:00
# 2020-02-19 00:00:00
# 2020-02-20 00:00:00
# 2020-02-20 00:00:00
# 2020-02-27 00:00:00
# 2020-01-17 00:00:00
# 2020-02-19 00:00:00
# 2020-02-07 00:00:00
# 2020-02-21 00:00:00
# 2020-02-12 00:00:00
# 2020-02-18 00:00:00
# 2020-02-20 00:00:00
# 2020-02-04 00:00:00
# 2020-02-18 00:00:00
# 2020-02-23 00:00:00
# 2020-02-09 00:00:00
# ...
